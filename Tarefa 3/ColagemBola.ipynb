# %% [markdown]
# <a href="https://colab.research.google.com/github/VitorRFC/ProcessamentoIMG/blob/master/ColagemBola.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import cv2
from matplotlib import pyplot as plt

def crop (messiImg, x_bola, y_bola, largura_bola, altura_bola):

  messiImg = cv2.cvtColor(messiImg, cv2.COLOR_BGR2RGB)
  plt.show()
  altura, largura, cores = messiImg.shape 
  ballImg = messiImg[y_bola:y_bola+altura_bola, x_bola:x_bola+largura_bola]
  plt.imshow(ballImg)
  paste(messiImg,ballImg,y_bola,x_bola)

def paste(destino, imagem, y, x):
  
  destino[280 : 280+imagem.shape[0], 130 : 130+imagem.shape[1]]=imagem
  plt.imshow(destino)

def main ():
  messiImg=cv2.imread("messi.jpg")
  x = 336
  y = 287
  largura = 55
  altura = 49
  crop(messiImg, x, y, largura, altura)



main()
